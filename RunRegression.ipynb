# %%
#这样就可以直接把pycharm里的py文件直接用了
import sys

if '/Users/mhuang/PycharmProjects/trytry' not in sys.path:
    sys.path.append('/Users/mhuang/PycharmProjects/trytry')

# %% [markdown]
# ### 1. 训练模型
# 前面还没给test的模式，所以长这样

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import config

# %%
features_train_encoded = pd.read_csv('/Users/mhuang/code/python/kaggle/features_train_encoded.csv')
labels_train = pd.read_csv('/Users/mhuang/code/python/kaggle/labels_train.csv')

#X_train, X_valid, y_train, y_valid = train_test_split(features_train_encoded, labels_train, test_size=0.10, random_state=42)
#感觉没必要弄出valid，因为我看它只是拿去用来early stop的

# %%
features_train_encoded = features_train_encoded.iloc[:,1:]
labels_train = labels_train.iloc[:,1:]

# %%
from model import myRegression

# %%
pipeline = myRegression(features_train_encoded, labels_train, config.SPLIT_SIZE, 'nnRegression')

# %%
loss=pipeline(epochs = config.EPOCHS)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [00:07<00:00,  7.08it/s]

# %%
loss
# Out:
# [tensor(1.5058, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.4984, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.4847, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.4660, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.4438, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.4191, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.3916, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.3619, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.3313, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.3007, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.2701, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.2399, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.2109, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.1836, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.1582, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.1353, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.1157, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0998, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0876, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0790, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0737, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0712, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0710, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0725, dtype=torch.float64, grad_fn=<MeanBackward0>)]

# %% [markdown]
# ### 2. 预测

# %%
sample_submission_encoded = pd.read_csv('sample_submission_encoded.csv')

# %%
feature_test = sample_submission_encoded.iloc[:,1:3]

# %%
pipeline = myRegression(features_train_encoded, labels_train, feature_test,
                        config.SPLIT_SIZE, 'nnRegression', submission=True)

# %%
loss,submission=pipeline(epochs = config.EPOCHS)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [00:17<00:00,  2.92it/s]

# %%
loss
# Out:
# [tensor(1.5058, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.3773, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.2571, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.1695, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.1168, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0836, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0573, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0414, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0330, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0275, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0214, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0172, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0142, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0119, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0101, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0090, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0081, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0073, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0060, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0046, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0031, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0021, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0011, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(1.0003, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9996, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9991, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9985, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9980, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9975, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9970, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9966, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9962, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9959, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9955, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9952, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9949, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9946, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9942, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9940, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9938, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9935, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9932, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9930, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9928, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9926, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9924, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9923, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9920, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9919, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9917, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9915, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9913, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.9913, dtype=torch.float64, grad_fn=<MeanBackward0>)]

# %%
submission
# Out:
#          A1BG  A1BG-AS1       A2M   A2M-AS1     A2MP1    A4GALT      AAAS  \
# 0    0.024057  0.469990 -0.078656  0.305895  0.664340  0.131157  0.167565
# 1    0.018123  0.450499 -0.080620  0.316603  0.639473  0.146542  0.145795
# 2    0.012453  0.430740 -0.083091  0.327207  0.612326  0.157963  0.124024
# 3    0.007628  0.404809 -0.084514  0.336380  0.587077  0.170441  0.105094
# 4    0.002329  0.374149 -0.086474  0.344664  0.562016  0.185484  0.088989
# ..        ...       ...       ...       ...       ...       ...       ...
# 250  0.339780  0.238501  0.091392 -0.001401  0.058798  0.036004  0.178822
# 251  0.351433  0.235868  0.098747 -0.018605  0.062441  0.033205  0.184706
# 252  0.362366  0.230201  0.102370 -0.033074  0.067189  0.036105  0.191715
# 253  0.373295  0.224530  0.105979 -0.047540  0.071934  0.039023  0.198731
# 254  0.384224  0.218859  0.109588 -0.062001  0.076677  0.041943  0.205748
#
#          AACS     AAGAB      AAK1  ...      ZUP1      ZW10    ZWILCH  \
# 0    0.200733 -0.037247  0.298187  ...  0.063273  0.061812 -0.373056
# 1    0.191583 -0.051281  0.288627  ...  0.062476  0.046142 -0.371267
# 2    0.183773 -0.065363  0.279669  ...  0.060372  0.030137 -0.368327
# 3    0.174176 -0.076974  0.272598  ...  0.057259  0.015196 -0.364989
# 4    0.166172 -0.084360  0.267333  ...  0.054063  0.000034 -0.361712
# ..        ...       ...       ...  ...       ...       ...       ...
# 250  0.513712  0.375343  0.136146  ... -0.184411  0.097314  0.254609
# 251  0.513913  0.394456  0.138520  ... -0.193899  0.097115  0.240901
# 252  0.513201  0.417262  0.141508  ... -0.204782  0.096452  0.223853
# 253  0.512485  0.440087  0.144490  ... -0.214398  0.096439  0.205883
# 254  0.511774  0.462914  0.147471  ... -0.222127  0.098256  0.187014
#
#         ZWINT      ZXDA      ZXDB      ZXDC    ZYG11B       ZYX     ZZEF1
# 0   -0.037422 -0.160028  0.576630 -0.216392  0.360261  0.027548  0.022945
# 1   -0.051971 -0.141835  0.568136 -0.212176  0.353843  0.034682  0.019814
# 2   -0.061497 -0.125901  0.558827 -0.212442  0.345420  0.041507  0.015443
# 3   -0.062473 -0.107474  0.548360 -0.214412  0.338940  0.051987  0.009069
# 4   -0.063291 -0.088892  0.538557 -0.215962  0.332302  0.062914  0.002209
# ..        ...       ...       ...       ...       ...       ...       ...
# 250 -0.143149  0.008056  0.129423 -0.161280  0.092460 -0.162240 -0.051301
# 251 -0.156400 -0.001656  0.125110 -0.160265  0.090715 -0.172213 -0.050521
# 252 -0.169725 -0.013970  0.124840 -0.161851  0.089976 -0.182850 -0.051109
# 253 -0.180236 -0.029398  0.126923 -0.162641  0.088169 -0.191877 -0.050839
# 254 -0.191155 -0.045357  0.131671 -0.162219  0.088000 -0.200364 -0.050781
#
# [255 rows x 18211 columns]

# %%
#最后提交的文件要在第一列加上id，格式对齐
sample_submission = pd.read_csv('sample_submission.csv')
my_submission = pd.concat([sample_submission.iloc[:,0],submission],axis=1)
my_submission.to_csv("my_submission.csv",index=False)

# %%
labels_train
# Out:
#          A1BG  A1BG-AS1       A2M   A2M-AS1     A2MP1    A4GALT      AAAS  \
